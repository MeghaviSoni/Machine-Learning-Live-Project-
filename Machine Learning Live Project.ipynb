# %%
import pandas as pd

# %%
data = pd.read_excel(r"C:\Users\Meghavi Soni\Downloads\ML PROJECT.xlsx",)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  datetime64[ns]
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(9)
# memory usage: 918.2+ KB

# %%
data.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1  Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#    Dep_Time         Arrival_Time Duration Total_Stops Additional_Info  Price
# 0  22:20:00  2024-03-22 01:10:00   2h 50m    non-stop         No info   3897
# 1  05:50:00             13:15:00   7h 25m     2 stops         No info   7662

# %%
data["Additional_Info"].value_counts()
# Out:
# Additional_Info
# No info                         8345
# In-flight meal not included     1982
# No check-in baggage included     320
# 1 Long layover                    19
# Change airports                    7
# Business class                     4
# No Info                            3
# 1 Short layover                    1
# Red-eye flight                     1
# 2 Long layover                     1
# Name: count, dtype: int64

# %%
data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
data[data["Total_Stops"].isnull()]
# Out:
#         Airline Date_of_Journey Source Destination Route  Dep_Time  \
# 9039  Air India      2019-05-06  Delhi      Cochin   NaN  09:45:00
#
#              Arrival_Time Duration Total_Stops Additional_Info  Price
# 9039  2024-05-07 09:25:00  23h 40m         NaN         No info   7480

# %%
data[data["Total_Stops"].isnull()].index
# Out:
# Index([9039], dtype='int64')

# %%
data.drop(9039,inplace=True)

# %%
data.drop(["Additional_Info","Route"],axis=1,inplace=True)

# %%
data
# Out:
#            Airline Date_of_Journey    Source Destination  Dep_Time  \
# 0           IndiGo      2019-03-24  Banglore   New Delhi  22:20:00
# 1        Air India      2019-05-01   Kolkata    Banglore  05:50:00
# 2      Jet Airways      2019-06-09     Delhi      Cochin  09:25:00
# 3           IndiGo      2019-05-12   Kolkata    Banglore  18:05:00
# 4           IndiGo      2019-03-01  Banglore   New Delhi  16:50:00
# ...            ...             ...       ...         ...       ...
# 10678     Air Asia      2019-04-09   Kolkata    Banglore  19:55:00
# 10679    Air India      2019-04-27   Kolkata    Banglore  20:45:00
# 10680  Jet Airways      2019-04-27  Banglore       Delhi  08:20:00
# 10681      Vistara      2019-03-01  Banglore   New Delhi  11:30:00
# 10682    Air India      2019-05-09     Delhi      Cochin  10:55:00
#
#               Arrival_Time Duration Total_Stops  Price
# 0      2024-03-22 01:10:00   2h 50m    non-stop   3897
# ...

# %%
import warnings 
warnings.filterwarnings("ignore")

# %%
data["j_mon"] = pd.to_datetime(data["Date_of_Journey"]).dt.month
data["j_day"] = pd.to_datetime(data["Date_of_Journey"]).dt.day

# %%
data
# Out:
#            Airline Date_of_Journey    Source Destination  Dep_Time  \
# 0           IndiGo      2019-03-24  Banglore   New Delhi  22:20:00
# 1        Air India      2019-05-01   Kolkata    Banglore  05:50:00
# 2      Jet Airways      2019-06-09     Delhi      Cochin  09:25:00
# 3           IndiGo      2019-05-12   Kolkata    Banglore  18:05:00
# 4           IndiGo      2019-03-01  Banglore   New Delhi  16:50:00
# ...            ...             ...       ...         ...       ...
# 10678     Air Asia      2019-04-09   Kolkata    Banglore  19:55:00
# 10679    Air India      2019-04-27   Kolkata    Banglore  20:45:00
# 10680  Jet Airways      2019-04-27  Banglore       Delhi  08:20:00
# 10681      Vistara      2019-03-01  Banglore   New Delhi  11:30:00
# 10682    Air India      2019-05-09     Delhi      Cochin  10:55:00
#
#               Arrival_Time Duration Total_Stops  Price  j_mon  j_day
# 0      2024-03-22 01:10:00   2h 50m    non-stop   3897      3     24
# ...

# %%
# data["Date_of_Journey"].str.split("/").str[1].astype(int)

# %%
# data["Arrival_Time"].str.split(" ").str[0].str.split(":").astype(int)

# %%
data["Arrival_Time"] = data["Arrival_Time"].astype(str)

# %%
data["Arrival_Time"] = pd.to_datetime(data["Arrival_Time"], format='mixed', errors='coerce')

# %%
data["Dep_Time"] = data["Dep_Time"].astype(str)

# %%
data["Dep_Time"] = pd.to_datetime(data["Dep_Time"], format="%H:%M:%S")

# %%
data["a_min"] = pd.to_datetime(data["Arrival_Time"]).dt.minute
data["d_min"] = pd.to_datetime(data["Dep_Time"]).dt.minute
data["a_hr"] = pd.to_datetime(data["Arrival_Time"]).dt.hour
data["d_hr"] = pd.to_datetime(data["Dep_Time"]).dt.hour

# %%
data
# Out:
#            Airline Date_of_Journey    Source Destination            Dep_Time  \
# 0           IndiGo      2019-03-24  Banglore   New Delhi 1900-01-01 22:20:00
# 1        Air India      2019-05-01   Kolkata    Banglore 1900-01-01 05:50:00
# 2      Jet Airways      2019-06-09     Delhi      Cochin 1900-01-01 09:25:00
# 3           IndiGo      2019-05-12   Kolkata    Banglore 1900-01-01 18:05:00
# 4           IndiGo      2019-03-01  Banglore   New Delhi 1900-01-01 16:50:00
# ...            ...             ...       ...         ...                 ...
# 10678     Air Asia      2019-04-09   Kolkata    Banglore 1900-01-01 19:55:00
# 10679    Air India      2019-04-27   Kolkata    Banglore 1900-01-01 20:45:00
# 10680  Jet Airways      2019-04-27  Banglore       Delhi 1900-01-01 08:20:00
# 10681      Vistara      2019-03-01  Banglore   New Delhi 1900-01-01 11:30:00
# 10682    Air India      2019-05-09     Delhi      Cochin 1900-01-01 10:55:00
#
# ...

# %%
lis = data["Duration"]

# %%
new_lis=[]
for i in lis:
    if len(i.split(" ")) == 1:
        if "m" in i:
            i = "0h " +i
        elif "h" in i:
            i=i+ " 0m"

    new_lis.append(i)

# %%
data["Duration"] = new_lis

# %%
data["du_hr"] = data["Duration"].str.split(" ").str[0].replace("h","",regex=True).astype(int)
data["Du_min"] = data["Duration"].str.split(" ").str[1].replace("m","",regex=True).astype(int)

# %%
data
# Out:
#            Airline Date_of_Journey    Source Destination            Dep_Time  \
# 0           IndiGo      2019-03-24  Banglore   New Delhi 1900-01-01 22:20:00
# 1        Air India      2019-05-01   Kolkata    Banglore 1900-01-01 05:50:00
# 2      Jet Airways      2019-06-09     Delhi      Cochin 1900-01-01 09:25:00
# 3           IndiGo      2019-05-12   Kolkata    Banglore 1900-01-01 18:05:00
# 4           IndiGo      2019-03-01  Banglore   New Delhi 1900-01-01 16:50:00
# ...            ...             ...       ...         ...                 ...
# 10678     Air Asia      2019-04-09   Kolkata    Banglore 1900-01-01 19:55:00
# 10679    Air India      2019-04-27   Kolkata    Banglore 1900-01-01 20:45:00
# 10680  Jet Airways      2019-04-27  Banglore       Delhi 1900-01-01 08:20:00
# 10681      Vistara      2019-03-01  Banglore   New Delhi 1900-01-01 11:30:00
# 10682    Air India      2019-05-09     Delhi      Cochin 1900-01-01 10:55:00
#
# ...

# %%
data["Total_Stops"].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', '4 stops'],
#       dtype=object)

# %%
data["Total_Stops"].replace(['non-stop', '2 stops', '1 stop', '3 stops', '4 stops'],[0,1,2,3,4],inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
enc = LabelEncoder()

# %%
data[["Airline","Source","Destination"]] = data[["Airline","Source","Destination"]].apply(enc.fit_transform)

# %%
data
# Out:
#        Airline Date_of_Journey  Source  Destination            Dep_Time  \
# 0            3      2019-03-24       0            5 1900-01-01 22:20:00
# 1            1      2019-05-01       3            0 1900-01-01 05:50:00
# 2            4      2019-06-09       2            1 1900-01-01 09:25:00
# 3            3      2019-05-12       3            0 1900-01-01 18:05:00
# 4            3      2019-03-01       0            5 1900-01-01 16:50:00
# ...        ...             ...     ...          ...                 ...
# 10678        0      2019-04-09       3            0 1900-01-01 19:55:00
# 10679        1      2019-04-27       3            0 1900-01-01 20:45:00
# 10680        4      2019-04-27       0            2 1900-01-01 08:20:00
# 10681       10      2019-03-01       0            5 1900-01-01 11:30:00
# 10682        1      2019-05-09       2            1 1900-01-01 10:55:00
#
#              Arrival_Time Duration  Total_Stops  Price  j_mon  j_day  a_min  \
# ...

# %%
data.drop(["Date_of_Journey","Dep_Time","Arrival_Time","Duration"],axis=1,inplace=True)

# %%
data
# Out:
#        Airline  Source  Destination  Total_Stops  Price  j_mon  j_day  a_min  \
# 0            3       0            5            0   3897      3     24     10
# 1            1       3            0            1   7662      5      1     15
# 2            4       2            1            1  13882      6      9     25
# 3            3       3            0            2   6218      5     12     30
# 4            3       0            5            2  13302      3      1     35
# ...        ...     ...          ...          ...    ...    ...    ...    ...
# 10678        0       3            0            0   4107      4      9     25
# 10679        1       3            0            0   4145      4     27     20
# 10680        4       0            2            0   7229      4     27     20
# 10681       10       0            5            0  12648      3      1     10
# 10682        1       2            1            1  11753      5      9     15
#
#        d_min  a_hr  d_hr  du_hr  Du_min
# ...

# %%
data.to_csv(r"C:\Users\Meghavi Soni\OneDrive\Documents\ML Live Project.csv")

# %%
data = pd.read_csv(r"C:\Users\Meghavi Soni\OneDrive\Documents\ML Live Project.csv")

# %%
data
# Out:
#        Unnamed: 0  Airline  Source  Destination  Total_Stops  Price  j_mon  \
# 0               0        3       0            5            0   3897      3
# 1               1        1       3            0            1   7662      5
# 2               2        4       2            1            1  13882      6
# 3               3        3       3            0            2   6218      5
# 4               4        3       0            5            2  13302      3
# ...           ...      ...     ...          ...          ...    ...    ...
# 10677       10678        0       3            0            0   4107      4
# 10678       10679        1       3            0            0   4145      4
# 10679       10680        4       0            2            0   7229      4
# 10680       10681       10       0            5            0  12648      3
# 10681       10682        1       2            1            1  11753      5
#
#        j_day  a_min  d_min  a_hr  d_hr  du_hr  Du_min
# ...

# %%
data.drop("Unnamed: 0",axis=1,inplace=True)

# %%
data
# Out:
#        Airline  Source  Destination  Total_Stops  Price  j_mon  j_day  a_min  \
# 0            3       0            5            0   3897      3     24     10
# 1            1       3            0            1   7662      5      1     15
# 2            4       2            1            1  13882      6      9     25
# 3            3       3            0            2   6218      5     12     30
# 4            3       0            5            2  13302      3      1     35
# ...        ...     ...          ...          ...    ...    ...    ...    ...
# 10677        0       3            0            0   4107      4      9     25
# 10678        1       3            0            0   4145      4     27     20
# 10679        4       0            2            0   7229      4     27     20
# 10680       10       0            5            0  12648      3      1     10
# 10681        1       2            1            1  11753      5      9     15
#
#        d_min  a_hr  d_hr  du_hr  Du_min
# ...

# %%
x = data.drop("Price",axis=1)

# %%
y = data["Price"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=0)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_train,y_train)
# Out:
# 0.39011923949935

# %%
model.score(x_test,y_test)
# Out:
# 0.37950771004334416

# %%
from sklearn.linear_model import Lasso,Ridge

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR

# %%
lis = [DecisionTreeRegressor,RandomForestRegressor,KNeighborsRegressor,SVR]

# %%
for i in lis:
    model = i()
    model.fit(x_train,y_train)
    print(i)
    print(model.score(x_train,y_train))
    print(model.score(x_test,y_test))
# Out:
# <class 'sklearn.tree._classes.DecisionTreeRegressor'>
# 0.9711683243930616
# 0.6318209039800209
# <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# 0.9538200251544602
# 0.7866268060280401
# <class 'sklearn.neighbors._regression.KNeighborsRegressor'>
# 0.7679755441373728
# 0.5668853359368404
# <class 'sklearn.svm._classes.SVR'>
# 0.006669736278777205
# -0.002790650428958319

# %%
from sklearn.model_selection import KFold,cross_val_score

# %%
h=KFold(5)

# %%
for i in lis:
    print(i)
    print(cross_val_score(i(),x,y,cv=h))
# Out:
# <class 'sklearn.tree._classes.DecisionTreeRegressor'>
# [0.63410068 0.75057007 0.70378647 0.69907627 0.65858975]
# <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# [0.81733075 0.81688804 0.8190846  0.80559792 0.76511397]
# <class 'sklearn.neighbors._regression.KNeighborsRegressor'>
# [0.59265718 0.63513173 0.61898956 0.59760537 0.63950889]
# <class 'sklearn.svm._classes.SVR'>
# [ 0.00364115 -0.0082522   0.01394215  0.01930455  0.00284072]

# %%
for i in lis:
    print(i)
    print(cross_val_score(i(),x,y,cv=h).mean())
# Out:
# <class 'sklearn.tree._classes.DecisionTreeRegressor'>
# 0.6885495819420333
# <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# 0.8066708828390663
# <class 'sklearn.neighbors._regression.KNeighborsRegressor'>
# 0.6167785455724557
# <class 'sklearn.svm._classes.SVR'>
# 0.006295272802113084

# %%
model2 = RandomForestRegressor()

# %%
model2.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
model2.score(x_test,y_test)
# Out:
# 0.786867743074352

# %%
model2.score(x_train,y_train)
# Out:
# 0.9527470957431875

# %%
n_estimators=[100,200,300]
random_state=[20,25,30,35]
max_depth=[2,3,4]
dict={"n_estimators":n_estimators,"random_state":random_state,"max_depth":max_depth}

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
grid = RandomizedSearchCV(model2,param_distributions=dict,n_iter=20,cv=KFold(5))

# %%
grid.fit(x,y)
# Out:
# RandomizedSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=False),
#                    estimator=RandomForestRegressor(), n_iter=20,
#                    param_distributions={'max_depth': [2, 3, 4],
#                                         'n_estimators': [100, 200, 300],
#                                         'random_state': [20, 25, 30, 35]})

# %%
grid.best_params_
# Out:
# {'random_state': 35, 'n_estimators': 300, 'max_depth': 4}

# %%
model2 = RandomForestRegressor(random_state= 35, n_estimators= 300, max_depth= 4)

# %%
model2.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=4, n_estimators=300, random_state=35)

# %%
model2.score(x_test,y_test)
# Out:
# 0.5981239689625952

# %%
model2.score(x_train,y_train)
# Out:
# 0.6500855007773398
